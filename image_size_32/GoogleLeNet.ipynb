# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

import torch
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader 
from torch.optim import Adam
import torchvision
import torchvision.models as models
from torchsummary import summary

torch.manual_seed(1)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Data

# %%
batch_size = 256
train_transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize([0.4914, 0.4822, 0.4465], 
                             [0.2470, 0.2435, 0.2616]),
    ])

val_transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize([0.4914, 0.4822, 0.4465], 
                             [0.2470, 0.2435, 0.2616])
    ])

train_set = CIFAR10(
    root='./data', 
    train=True,
    download=True, 
    transform=train_transform
)

val_set = CIFAR10(
    root='./data', 
    train=False,
    download=True, 
    transform=val_transform
)

trainloader = DataLoader(
    train_set, 
    batch_size=batch_size,
    shuffle=True,
    num_workers=4,
)

testloader = DataLoader(
    val_set, 
    batch_size=batch_size,
    shuffle=False, 
    num_workers=4,
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Model

# %%
class Inception(nn.Module):
    def __init__(self, in_planes, n1x1, n3x3red, n3x3, n5x5red, n5x5, pool_planes):
        super(Inception, self).__init__()
        # 1x1 conv branch
        self.b1 = nn.Sequential(
            nn.Conv2d(in_planes, n1x1, kernel_size=1),
            nn.BatchNorm2d(n1x1),
            nn.ReLU(True),
        )

        # 1x1 conv -> 3x3 conv branch
        self.b2 = nn.Sequential(
            nn.Conv2d(in_planes, n3x3red, kernel_size=1),
            nn.BatchNorm2d(n3x3red),
            nn.ReLU(True),
            nn.Conv2d(n3x3red, n3x3, kernel_size=3, padding=1),
            nn.BatchNorm2d(n3x3),
            nn.ReLU(True),
        )

        # 1x1 conv -> 5x5 conv branch
        self.b3 = nn.Sequential(
            nn.Conv2d(in_planes, n5x5red, kernel_size=1),
            nn.BatchNorm2d(n5x5red),
            nn.ReLU(True),
            nn.Conv2d(n5x5red, n5x5, kernel_size=3, padding=1),
            nn.BatchNorm2d(n5x5),
            nn.ReLU(True),
            nn.Conv2d(n5x5, n5x5, kernel_size=3, padding=1),
            nn.BatchNorm2d(n5x5),
            nn.ReLU(True),
        )

        # 3x3 pool -> 1x1 conv branch
        self.b4 = nn.Sequential(
            nn.MaxPool2d(3, stride=1, padding=1),
            nn.Conv2d(in_planes, pool_planes, kernel_size=1),
            nn.BatchNorm2d(pool_planes),
            nn.ReLU(True),
        )

    def forward(self, x):
        y1 = self.b1(x)
        y2 = self.b2(x)
        y3 = self.b3(x)
        y4 = self.b4(x)
        return torch.cat([y1,y2,y3,y4], 1)


class GoogLeNet(nn.Module):
    def __init__(self, num_classes=10):
        super(GoogLeNet, self).__init__()
        self.pre_layers = nn.Sequential(
            nn.Conv2d(3, 192, kernel_size=3, padding=1),
            nn.BatchNorm2d(192),
            nn.ReLU(True),
        )

        self.a3 = Inception(192,  64,  96, 128, 16, 32, 32)
        self.b3 = Inception(256, 128, 128, 192, 32, 96, 64)

        self.maxpool = nn.MaxPool2d(3, stride=2, padding=1)

        self.a4 = Inception(480, 192,  96, 208, 16,  48,  64)
        self.b4 = Inception(512, 160, 112, 224, 24,  64,  64)
        self.c4 = Inception(512, 128, 128, 256, 24,  64,  64)
        self.d4 = Inception(512, 112, 144, 288, 32,  64,  64)
        self.e4 = Inception(528, 256, 160, 320, 32, 128, 128)

        self.a5 = Inception(832, 256, 160, 320, 32, 128, 128)
        self.b5 = Inception(832, 384, 192, 384, 48, 128, 128)

        self.avgpool = nn.AvgPool2d(8, stride=1)
        self.linear = nn.Linear(1024, num_classes)

    def forward(self, x):
        out = self.pre_layers(x)
        out = self.a3(out)
        out = self.b3(out)
        out = self.maxpool(out)
        out = self.a4(out)
        out = self.b4(out)
        out = self.c4(out)
        out = self.d4(out)
        out = self.e4(out)
        out = self.maxpool(out)
        out = self.a5(out)
        out = self.b5(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = GoogLeNet(num_classes=10).to(device)

# %%
summary(model, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 192, 32, 32]           5,376
#        BatchNorm2d-2          [-1, 192, 32, 32]             384
#               ReLU-3          [-1, 192, 32, 32]               0
#             Conv2d-4           [-1, 64, 32, 32]          12,352
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#               ReLU-6           [-1, 64, 32, 32]               0
#             Conv2d-7           [-1, 96, 32, 32]          18,528
#        BatchNorm2d-8           [-1, 96, 32, 32]             192
#               ReLU-9           [-1, 96, 32, 32]               0
#            Conv2d-10          [-1, 128, 32, 32]         110,720
#       BatchNorm2d-11          [-1, 128, 32, 32]             256
#              ReLU-12          [-1, 128, 32, 32]               0
#            Conv2d-13           [-1, 16, 32, 32]           3,088
#       BatchNorm2d-14           [-1, 16, 32, 32]              32
#              ReLU-15           [-1, 16, 32, 32]               0
#            Conv2d-16           [-1, 32, 32, 32]           4,640
#       BatchNorm2d-17           [-1, 32, 32, 32]              64
#              ReLU-18           [-1, 32, 32, 32]               0
#            Conv2d-19           [-1, 32, 32, 32]           9,248
#       BatchNorm2d-20           [-1, 32, 32, 32]              64
#              ReLU-21           [-1, 32, 32, 32]               0
#         MaxPool2d-22          [-1, 192, 32, 32]               0
#            Conv2d-23           [-1, 32, 32, 32]           6,176
#       BatchNorm2d-24           [-1, 32, 32, 32]              64
#              ReLU-25           [-1, 32, 32, 32]               0
#         Inception-26          [-1, 256, 32, 32]               0
#            Conv2d-27          [-1, 128, 32, 32]          32,896
#       BatchNorm2d-28          [-1, 128, 32, 32]             256
#              ReLU-29          [-1, 128, 32, 32]               0
#            Conv2d-30          [-1, 128, 32, 32]          32,896
#       BatchNorm2d-31          [-1, 128, 32, 32]             256
#              ReLU-32          [-1, 128, 32, 32]               0
#            Conv2d-33          [-1, 192, 32, 32]         221,376
#       BatchNorm2d-34          [-1, 192, 32, 32]             384
#              ReLU-35          [-1, 192, 32, 32]               0
#            Conv2d-36           [-1, 32, 32, 32]           8,224
#       BatchNorm2d-37           [-1, 32, 32, 32]              64
#              ReLU-38           [-1, 32, 32, 32]               0
#            Conv2d-39           [-1, 96, 32, 32]          27,744
#       BatchNorm2d-40           [-1, 96, 32, 32]             192
#              ReLU-41           [-1, 96, 32, 32]               0
#            Conv2d-42           [-1, 96, 32, 32]          83,040
#       BatchNorm2d-43           [-1, 96, 32, 32]             192
#              ReLU-44           [-1, 96, 32, 32]               0
#         MaxPool2d-45          [-1, 256, 32, 32]               0
#            Conv2d-46           [-1, 64, 32, 32]          16,448
#       BatchNorm2d-47           [-1, 64, 32, 32]             128
#              ReLU-48           [-1, 64, 32, 32]               0
#         Inception-49          [-1, 480, 32, 32]               0
#         MaxPool2d-50          [-1, 480, 16, 16]               0
#            Conv2d-51          [-1, 192, 16, 16]          92,352
#       BatchNorm2d-52          [-1, 192, 16, 16]             384
#              ReLU-53          [-1, 192, 16, 16]               0
#            Conv2d-54           [-1, 96, 16, 16]          46,176
#       BatchNorm2d-55           [-1, 96, 16, 16]             192
#              ReLU-56           [-1, 96, 16, 16]               0
#            Conv2d-57          [-1, 208, 16, 16]         179,920
#       BatchNorm2d-58          [-1, 208, 16, 16]             416
#              ReLU-59          [-1, 208, 16, 16]               0
#            Conv2d-60           [-1, 16, 16, 16]           7,696
#       BatchNorm2d-61           [-1, 16, 16, 16]              32
#              ReLU-62           [-1, 16, 16, 16]               0
#            Conv2d-63           [-1, 48, 16, 16]           6,960
#       BatchNorm2d-64           [-1, 48, 16, 16]              96
#              ReLU-65           [-1, 48, 16, 16]               0
#            Conv2d-66           [-1, 48, 16, 16]          20,784
#       BatchNorm2d-67           [-1, 48, 16, 16]              96
#              ReLU-68           [-1, 48, 16, 16]               0
#         MaxPool2d-69          [-1, 480, 16, 16]               0
#            Conv2d-70           [-1, 64, 16, 16]          30,784
#       BatchNorm2d-71           [-1, 64, 16, 16]             128
#              ReLU-72           [-1, 64, 16, 16]               0
#         Inception-73          [-1, 512, 16, 16]               0
#            Conv2d-74          [-1, 160, 16, 16]          82,080
#       BatchNorm2d-75          [-1, 160, 16, 16]             320
#              ReLU-76          [-1, 160, 16, 16]               0
#            Conv2d-77          [-1, 112, 16, 16]          57,456
#       BatchNorm2d-78          [-1, 112, 16, 16]             224
#              ReLU-79          [-1, 112, 16, 16]               0
#            Conv2d-80          [-1, 224, 16, 16]         226,016
#       BatchNorm2d-81          [-1, 224, 16, 16]             448
#              ReLU-82          [-1, 224, 16, 16]               0
#            Conv2d-83           [-1, 24, 16, 16]          12,312
#       BatchNorm2d-84           [-1, 24, 16, 16]              48
#              ReLU-85           [-1, 24, 16, 16]               0
#            Conv2d-86           [-1, 64, 16, 16]          13,888
#       BatchNorm2d-87           [-1, 64, 16, 16]             128
#              ReLU-88           [-1, 64, 16, 16]               0
#            Conv2d-89           [-1, 64, 16, 16]          36,928
#       BatchNorm2d-90           [-1, 64, 16, 16]             128
#              ReLU-91           [-1, 64, 16, 16]               0
#         MaxPool2d-92          [-1, 512, 16, 16]               0
#            Conv2d-93           [-1, 64, 16, 16]          32,832
#       BatchNorm2d-94           [-1, 64, 16, 16]             128
#              ReLU-95           [-1, 64, 16, 16]               0
#         Inception-96          [-1, 512, 16, 16]               0
#            Conv2d-97          [-1, 128, 16, 16]          65,664
#       BatchNorm2d-98          [-1, 128, 16, 16]             256
#              ReLU-99          [-1, 128, 16, 16]               0
#           Conv2d-100          [-1, 128, 16, 16]          65,664
#      BatchNorm2d-101          [-1, 128, 16, 16]             256
#             ReLU-102          [-1, 128, 16, 16]               0
#           Conv2d-103          [-1, 256, 16, 16]         295,168
#      BatchNorm2d-104          [-1, 256, 16, 16]             512
#             ReLU-105          [-1, 256, 16, 16]               0
#           Conv2d-106           [-1, 24, 16, 16]          12,312
#      BatchNorm2d-107           [-1, 24, 16, 16]              48
#             ReLU-108           [-1, 24, 16, 16]               0
#           Conv2d-109           [-1, 64, 16, 16]          13,888
#      BatchNorm2d-110           [-1, 64, 16, 16]             128
#             ReLU-111           [-1, 64, 16, 16]               0
#           Conv2d-112           [-1, 64, 16, 16]          36,928
#      BatchNorm2d-113           [-1, 64, 16, 16]             128
#             ReLU-114           [-1, 64, 16, 16]               0
#        MaxPool2d-115          [-1, 512, 16, 16]               0
#           Conv2d-116           [-1, 64, 16, 16]          32,832
#      BatchNorm2d-117           [-1, 64, 16, 16]             128
#             ReLU-118           [-1, 64, 16, 16]               0
#        Inception-119          [-1, 512, 16, 16]               0
#           Conv2d-120          [-1, 112, 16, 16]          57,456
#      BatchNorm2d-121          [-1, 112, 16, 16]             224
#             ReLU-122          [-1, 112, 16, 16]               0
#           Conv2d-123          [-1, 144, 16, 16]          73,872
#      BatchNorm2d-124          [-1, 144, 16, 16]             288
#             ReLU-125          [-1, 144, 16, 16]               0
#           Conv2d-126          [-1, 288, 16, 16]         373,536
#      BatchNorm2d-127          [-1, 288, 16, 16]             576
#             ReLU-128          [-1, 288, 16, 16]               0
#           Conv2d-129           [-1, 32, 16, 16]          16,416
#      BatchNorm2d-130           [-1, 32, 16, 16]              64
#             ReLU-131           [-1, 32, 16, 16]               0
#           Conv2d-132           [-1, 64, 16, 16]          18,496
#      BatchNorm2d-133           [-1, 64, 16, 16]             128
#             ReLU-134           [-1, 64, 16, 16]               0
#           Conv2d-135           [-1, 64, 16, 16]          36,928
#      BatchNorm2d-136           [-1, 64, 16, 16]             128
#             ReLU-137           [-1, 64, 16, 16]               0
#        MaxPool2d-138          [-1, 512, 16, 16]               0
#           Conv2d-139           [-1, 64, 16, 16]          32,832
#      BatchNorm2d-140           [-1, 64, 16, 16]             128
#             ReLU-141           [-1, 64, 16, 16]               0
#        Inception-142          [-1, 528, 16, 16]               0
#           Conv2d-143          [-1, 256, 16, 16]         135,424
#      BatchNorm2d-144          [-1, 256, 16, 16]             512
#             ReLU-145          [-1, 256, 16, 16]               0
#           Conv2d-146          [-1, 160, 16, 16]          84,640
#      BatchNorm2d-147          [-1, 160, 16, 16]             320
#             ReLU-148          [-1, 160, 16, 16]               0
#           Conv2d-149          [-1, 320, 16, 16]         461,120
#      BatchNorm2d-150          [-1, 320, 16, 16]             640
#             ReLU-151          [-1, 320, 16, 16]               0
#           Conv2d-152           [-1, 32, 16, 16]          16,928
#      BatchNorm2d-153           [-1, 32, 16, 16]              64
#             ReLU-154           [-1, 32, 16, 16]               0
#           Conv2d-155          [-1, 128, 16, 16]          36,992
#      BatchNorm2d-156          [-1, 128, 16, 16]             256
#             ReLU-157          [-1, 128, 16, 16]               0
#           Conv2d-158          [-1, 128, 16, 16]         147,584
#      BatchNorm2d-159          [-1, 128, 16, 16]             256
#             ReLU-160          [-1, 128, 16, 16]               0
#        MaxPool2d-161          [-1, 528, 16, 16]               0
#           Conv2d-162          [-1, 128, 16, 16]          67,712
#      BatchNorm2d-163          [-1, 128, 16, 16]             256
#             ReLU-164          [-1, 128, 16, 16]               0
#        Inception-165          [-1, 832, 16, 16]               0
#        MaxPool2d-166            [-1, 832, 8, 8]               0
#           Conv2d-167            [-1, 256, 8, 8]         213,248
#      BatchNorm2d-168            [-1, 256, 8, 8]             512
#             ReLU-169            [-1, 256, 8, 8]               0
#           Conv2d-170            [-1, 160, 8, 8]         133,280
#      BatchNorm2d-171            [-1, 160, 8, 8]             320
#             ReLU-172            [-1, 160, 8, 8]               0
#           Conv2d-173            [-1, 320, 8, 8]         461,120
#      BatchNorm2d-174            [-1, 320, 8, 8]             640
#             ReLU-175            [-1, 320, 8, 8]               0
#           Conv2d-176             [-1, 32, 8, 8]          26,656
#      BatchNorm2d-177             [-1, 32, 8, 8]              64
#             ReLU-178             [-1, 32, 8, 8]               0
#           Conv2d-179            [-1, 128, 8, 8]          36,992
#      BatchNorm2d-180            [-1, 128, 8, 8]             256
#             ReLU-181            [-1, 128, 8, 8]               0
#           Conv2d-182            [-1, 128, 8, 8]         147,584
#      BatchNorm2d-183            [-1, 128, 8, 8]             256
#             ReLU-184            [-1, 128, 8, 8]               0
#        MaxPool2d-185            [-1, 832, 8, 8]               0
#           Conv2d-186            [-1, 128, 8, 8]         106,624
#      BatchNorm2d-187            [-1, 128, 8, 8]             256
#             ReLU-188            [-1, 128, 8, 8]               0
#        Inception-189            [-1, 832, 8, 8]               0
#           Conv2d-190            [-1, 384, 8, 8]         319,872
#      BatchNorm2d-191            [-1, 384, 8, 8]             768
#             ReLU-192            [-1, 384, 8, 8]               0
#           Conv2d-193            [-1, 192, 8, 8]         159,936
#      BatchNorm2d-194            [-1, 192, 8, 8]             384
#             ReLU-195            [-1, 192, 8, 8]               0
#           Conv2d-196            [-1, 384, 8, 8]         663,936
#      BatchNorm2d-197            [-1, 384, 8, 8]             768
#             ReLU-198            [-1, 384, 8, 8]               0
#           Conv2d-199             [-1, 48, 8, 8]          39,984
#      BatchNorm2d-200             [-1, 48, 8, 8]              96
#             ReLU-201             [-1, 48, 8, 8]               0
#           Conv2d-202            [-1, 128, 8, 8]          55,424
#      BatchNorm2d-203            [-1, 128, 8, 8]             256
#             ReLU-204            [-1, 128, 8, 8]               0
#           Conv2d-205            [-1, 128, 8, 8]         147,584
#      BatchNorm2d-206            [-1, 128, 8, 8]             256
#             ReLU-207            [-1, 128, 8, 8]               0
#        MaxPool2d-208            [-1, 832, 8, 8]               0
#           Conv2d-209            [-1, 128, 8, 8]         106,624
#      BatchNorm2d-210            [-1, 128, 8, 8]             256
#             ReLU-211            [-1, 128, 8, 8]               0
#        Inception-212           [-1, 1024, 8, 8]               0
#        AvgPool2d-213           [-1, 1024, 1, 1]               0
#           Linear-214                   [-1, 10]          10,250
# ================================================================
# Total params: 6,166,250
# Trainable params: 6,166,250
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 81.42
# Params size (MB): 23.52
# Estimated Total Size (MB): 104.96
# ----------------------------------------------------------------

# %% [markdown]
# # Train

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-3)

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    running_correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            running_correct += (predicted == labels).sum().item()

    accuracy = 100 * running_correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
# some parameter
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 150

# %%
# train
for epoch in range(max_epoch):
    model.train()
    running_loss = 0.0
    running_correct = 0   # to track number of correct predictions
    total = 0             # to track total number of samples

    for i, (inputs, labels) in enumerate(trainloader, 0):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()  
    
        # Determine class predictions and track accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()


    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    
    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{(epoch + 1):3}/{max_epoch:3}] \t Loss: {epoch_loss:<11.5f} Accuracy: {epoch_accuracy:.2f}% \t Test Loss: {test_loss:<11.5f} Test Accuracy: {test_accuracy:.2f}%")
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [  1/150] 	 Loss: 1.21031     Accuracy: 55.81% 	 Test Loss: 1.30190     Test Accuracy: 56.80%
# Epoch [  2/150] 	 Loss: 0.73486     Accuracy: 74.08% 	 Test Loss: 0.93844     Test Accuracy: 68.36%
# Epoch [  3/150] 	 Loss: 0.54140     Accuracy: 81.16% 	 Test Loss: 1.20150     Test Accuracy: 62.65%
# Epoch [  4/150] 	 Loss: 0.42868     Accuracy: 85.31% 	 Test Loss: 0.85204     Test Accuracy: 73.42%
# Epoch [  5/150] 	 Loss: 0.34788     Accuracy: 88.03% 	 Test Loss: 0.56109     Test Accuracy: 82.02%
# Epoch [  6/150] 	 Loss: 0.29026     Accuracy: 89.96% 	 Test Loss: 0.63893     Test Accuracy: 79.93%
# Epoch [  7/150] 	 Loss: 0.23573     Accuracy: 91.87% 	 Test Loss: 0.58675     Test Accuracy: 81.62%
# Epoch [  8/150] 	 Loss: 0.19170     Accuracy: 93.35% 	 Test Loss: 0.49480     Test Accuracy: 84.72%
# Epoch [  9/150] 	 Loss: 0.15858     Accuracy: 94.49% 	 Test Loss: 0.69196     Test Accuracy: 80.55%
# Epoch [ 10/150] 	 Loss: 0.13076     Accuracy: 95.53% 	 Test Loss: 0.65997     Test Accuracy: 82.50%
# Epoch [ 11/150] 	 Loss: 0.10924     Accuracy: 96.21% 	 Test Loss: 0.64479     Test Accuracy: 83.48%
# Epoch [ 12/150] 	 Loss: 0.09381     Accuracy: 96.60% 	 Test Loss: 0.73042     Test Accuracy: 82.00%
# Epoch [ 13/150] 	 Loss: 0.08658     Accuracy: 96.94% 	 Test Loss: 0.68663     Test Accuracy: 83.75%
# Epoch [ 14/150] 	 Loss: 0.06879     Accuracy: 97.54% 	 Test Loss: 0.63955     Test Accuracy: 84.33%
# Epoch [ 15/150] 	 Loss: 0.06363     Accuracy: 97.74% 	 Test Loss: 0.53792     Test Accuracy: 86.81%
# Epoch [ 16/150] 	 Loss: 0.06000     Accuracy: 97.90% 	 Test Loss: 0.61852     Test Accuracy: 85.80%
# Epoch [ 17/150] 	 Loss: 0.05425     Accuracy: 98.09% 	 Test Loss: 0.52844     Test Accuracy: 87.80%
# Epoch [ 18/150] 	 Loss: 0.04005     Accuracy: 98.59% 	 Test Loss: 0.78353     Test Accuracy: 84.52%
# Epoch [ 19/150] 	 Loss: 0.05626     Accuracy: 98.13% 	 Test Loss: 0.72426     Test Accuracy: 85.12%
# Epoch [ 20/150] 	 Loss: 0.05524     Accuracy: 98.04% 	 Test Loss: 0.74496     Test Accuracy: 84.09%
# Epoch [ 21/150] 	 Loss: 0.03129     Accuracy: 98.90% 	 Test Loss: 0.60863     Test Accuracy: 87.10%
# Epoch [ 22/150] 	 Loss: 0.04169     Accuracy: 98.56% 	 Test Loss: 0.75506     Test Accuracy: 83.65%
# Epoch [ 23/150] 	 Loss: 0.03823     Accuracy: 98.69% 	 Test Loss: 0.60808     Test Accuracy: 87.18%
# Epoch [ 24/150] 	 Loss: 0.03360     Accuracy: 98.88% 	 Test Loss: 0.76627     Test Accuracy: 84.48%
# Epoch [ 25/150] 	 Loss: 0.03936     Accuracy: 98.64% 	 Test Loss: 0.56880     Test Accuracy: 87.87%
# Epoch [ 26/150] 	 Loss: 0.02845     Accuracy: 99.05% 	 Test Loss: 0.70519     Test Accuracy: 85.35%
# Epoch [ 27/150] 	 Loss: 0.03940     Accuracy: 98.66% 	 Test Loss: 0.70886     Test Accuracy: 85.91%
# Epoch [ 28/150] 	 Loss: 0.03443     Accuracy: 98.78% 	 Test Loss: 0.96418     Test Accuracy: 82.11%
# Epoch [ 29/150] 	 Loss: 0.02786     Accuracy: 99.07% 	 Test Loss: 0.66624     Test Accuracy: 86.87%
# Epoch [ 30/150] 	 Loss: 0.03511     Accuracy: 98.76% 	 Test Loss: 0.69315     Test Accuracy: 85.57%
# Epoch [ 31/150] 	 Loss: 0.02462     Accuracy: 99.18% 	 Test Loss: 0.59571     Test Accuracy: 88.35%
# Epoch [ 32/150] 	 Loss: 0.02285     Accuracy: 99.22% 	 Test Loss: 0.63689     Test Accuracy: 87.87%
# Epoch [ 33/150] 	 Loss: 0.02519     Accuracy: 99.11% 	 Test Loss: 0.62763     Test Accuracy: 88.14%
# Epoch [ 34/150] 	 Loss: 0.01928     Accuracy: 99.34% 	 Test Loss: 0.65886     Test Accuracy: 87.14%
# Epoch [ 35/150] 	 Loss: 0.03832     Accuracy: 98.70% 	 Test Loss: 0.69041     Test Accuracy: 86.45%
# Epoch [ 36/150] 	 Loss: 0.03358     Accuracy: 98.86% 	 Test Loss: 0.72502     Test Accuracy: 85.97%
# Epoch [ 37/150] 	 Loss: 0.01656     Accuracy: 99.39% 	 Test Loss: 0.59409     Test Accuracy: 88.80%
# Epoch [ 38/150] 	 Loss: 0.01993     Accuracy: 99.34% 	 Test Loss: 0.75719     Test Accuracy: 86.20%
# Epoch [ 39/150] 	 Loss: 0.02344     Accuracy: 99.15% 	 Test Loss: 0.61683     Test Accuracy: 88.19%
# Epoch [ 40/150] 	 Loss: 0.02451     Accuracy: 99.18% 	 Test Loss: 0.57298     Test Accuracy: 88.69%
# Epoch [ 41/150] 	 Loss: 0.02086     Accuracy: 99.28% 	 Test Loss: 0.71962     Test Accuracy: 87.09%
# Epoch [ 42/150] 	 Loss: 0.02456     Accuracy: 99.18% 	 Test Loss: 0.74031     Test Accuracy: 87.00%
# Epoch [ 43/150] 	 Loss: 0.01432     Accuracy: 99.53% 	 Test Loss: 0.78483     Test Accuracy: 86.67%
# Epoch [ 44/150] 	 Loss: 0.01817     Accuracy: 99.39% 	 Test Loss: 0.85018     Test Accuracy: 85.46%
# Epoch [ 45/150] 	 Loss: 0.02418     Accuracy: 99.12% 	 Test Loss: 0.87955     Test Accuracy: 84.26%
# Epoch [ 46/150] 	 Loss: 0.01773     Accuracy: 99.36% 	 Test Loss: 0.74328     Test Accuracy: 86.87%
# Epoch [ 47/150] 	 Loss: 0.01724     Accuracy: 99.43% 	 Test Loss: 0.67575     Test Accuracy: 88.21%
# Epoch [ 48/150] 	 Loss: 0.01849     Accuracy: 99.35% 	 Test Loss: 0.62365     Test Accuracy: 88.60%
# Epoch [ 49/150] 	 Loss: 0.01548     Accuracy: 99.47% 	 Test Loss: 0.64625     Test Accuracy: 88.64%
# Epoch [ 50/150] 	 Loss: 0.02188     Accuracy: 99.25% 	 Test Loss: 0.62170     Test Accuracy: 88.15%
# Epoch [ 51/150] 	 Loss: 0.01681     Accuracy: 99.46% 	 Test Loss: 0.70198     Test Accuracy: 87.34%
# Epoch [ 52/150] 	 Loss: 0.01670     Accuracy: 99.41% 	 Test Loss: 0.72761     Test Accuracy: 87.54%
# Epoch [ 53/150] 	 Loss: 0.01998     Accuracy: 99.36% 	 Test Loss: 0.70405     Test Accuracy: 88.31%
# Epoch [ 54/150] 	 Loss: 0.01843     Accuracy: 99.36% 	 Test Loss: 0.68442     Test Accuracy: 87.88%
# Epoch [ 55/150] 	 Loss: 0.00898     Accuracy: 99.71% 	 Test Loss: 0.73952     Test Accuracy: 87.59%
# Epoch [ 56/150] 	 Loss: 0.00851     Accuracy: 99.72% 	 Test Loss: 0.62806     Test Accuracy: 89.50%
# Epoch [ 57/150] 	 Loss: 0.01799     Accuracy: 99.40% 	 Test Loss: 0.72241     Test Accuracy: 87.11%
# Epoch [ 58/150] 	 Loss: 0.01883     Accuracy: 99.35% 	 Test Loss: 0.71060     Test Accuracy: 87.97%
# Epoch [ 59/150] 	 Loss: 0.01657     Accuracy: 99.42% 	 Test Loss: 0.64215     Test Accuracy: 88.34%
# Epoch [ 60/150] 	 Loss: 0.02415     Accuracy: 99.20% 	 Test Loss: 0.68066     Test Accuracy: 87.73%
# Epoch [ 61/150] 	 Loss: 0.00994     Accuracy: 99.66% 	 Test Loss: 0.58521     Test Accuracy: 89.24%
# Epoch [ 62/150] 	 Loss: 0.01134     Accuracy: 99.65% 	 Test Loss: 0.86121     Test Accuracy: 86.40%
# Epoch [ 63/150] 	 Loss: 0.00905     Accuracy: 99.71% 	 Test Loss: 0.72783     Test Accuracy: 87.76%
# Epoch [ 64/150] 	 Loss: 0.01603     Accuracy: 99.46% 	 Test Loss: 0.74106     Test Accuracy: 87.71%
# Epoch [ 65/150] 	 Loss: 0.01360     Accuracy: 99.53% 	 Test Loss: 0.60434     Test Accuracy: 89.15%
# Epoch [ 66/150] 	 Loss: 0.00942     Accuracy: 99.66% 	 Test Loss: 0.60569     Test Accuracy: 89.73%
# Epoch [ 67/150] 	 Loss: 0.00757     Accuracy: 99.74% 	 Test Loss: 0.72412     Test Accuracy: 88.26%
# Epoch [ 68/150] 	 Loss: 0.02068     Accuracy: 99.30% 	 Test Loss: 0.72081     Test Accuracy: 88.13%
# Epoch [ 69/150] 	 Loss: 0.01089     Accuracy: 99.63% 	 Test Loss: 0.68822     Test Accuracy: 88.93%
# Epoch [ 70/150] 	 Loss: 0.01012     Accuracy: 99.65% 	 Test Loss: 0.89747     Test Accuracy: 86.51%
# Epoch [ 71/150] 	 Loss: 0.01938     Accuracy: 99.34% 	 Test Loss: 0.68761     Test Accuracy: 88.40%
# Epoch [ 72/150] 	 Loss: 0.01960     Accuracy: 99.31% 	 Test Loss: 0.69926     Test Accuracy: 88.29%
# Epoch [ 73/150] 	 Loss: 0.01044     Accuracy: 99.69% 	 Test Loss: 0.68741     Test Accuracy: 88.21%
# Epoch [ 74/150] 	 Loss: 0.00770     Accuracy: 99.75% 	 Test Loss: 0.57459     Test Accuracy: 90.10%
# Epoch [ 75/150] 	 Loss: 0.00291     Accuracy: 99.94% 	 Test Loss: 0.64748     Test Accuracy: 89.24%
# Epoch [ 76/150] 	 Loss: 0.00523     Accuracy: 99.83% 	 Test Loss: 0.75266     Test Accuracy: 88.54%
# Epoch [ 77/150] 	 Loss: 0.02103     Accuracy: 99.27% 	 Test Loss: 1.81037     Test Accuracy: 76.68%
# Epoch [ 78/150] 	 Loss: 0.01438     Accuracy: 99.53% 	 Test Loss: 0.68911     Test Accuracy: 88.50%
# Epoch [ 79/150] 	 Loss: 0.00972     Accuracy: 99.64% 	 Test Loss: 0.73160     Test Accuracy: 88.32%
# Epoch [ 80/150] 	 Loss: 0.00933     Accuracy: 99.69% 	 Test Loss: 0.67241     Test Accuracy: 89.21%
# Epoch [ 81/150] 	 Loss: 0.00704     Accuracy: 99.77% 	 Test Loss: 0.63082     Test Accuracy: 89.32%
# Epoch [ 82/150] 	 Loss: 0.00896     Accuracy: 99.70% 	 Test Loss: 0.65813     Test Accuracy: 89.17%
# Epoch [ 83/150] 	 Loss: 0.00906     Accuracy: 99.68% 	 Test Loss: 0.67045     Test Accuracy: 89.39%
# Epoch [ 84/150] 	 Loss: 0.00868     Accuracy: 99.69% 	 Test Loss: 0.88524     Test Accuracy: 86.43%
# Epoch [ 85/150] 	 Loss: 0.02049     Accuracy: 99.31% 	 Test Loss: 0.61090     Test Accuracy: 89.60%
# Epoch [ 86/150] 	 Loss: 0.00863     Accuracy: 99.68% 	 Test Loss: 0.67686     Test Accuracy: 89.10%
# Epoch [ 87/150] 	 Loss: 0.00763     Accuracy: 99.75% 	 Test Loss: 0.65218     Test Accuracy: 89.46%
# Epoch [ 88/150] 	 Loss: 0.00602     Accuracy: 99.80% 	 Test Loss: 0.57999     Test Accuracy: 90.14%
# Epoch [ 89/150] 	 Loss: 0.00915     Accuracy: 99.66% 	 Test Loss: 0.71964     Test Accuracy: 88.47%
# Epoch [ 90/150] 	 Loss: 0.01494     Accuracy: 99.52% 	 Test Loss: 0.63270     Test Accuracy: 89.38%
# Epoch [ 91/150] 	 Loss: 0.00682     Accuracy: 99.78% 	 Test Loss: 0.63850     Test Accuracy: 89.68%
# Epoch [ 92/150] 	 Loss: 0.00649     Accuracy: 99.79% 	 Test Loss: 0.73958     Test Accuracy: 88.76%
# Epoch [ 93/150] 	 Loss: 0.00753     Accuracy: 99.74% 	 Test Loss: 0.65783     Test Accuracy: 89.20%
# Epoch [ 94/150] 	 Loss: 0.00959     Accuracy: 99.65% 	 Test Loss: 0.75263     Test Accuracy: 88.29%
# Epoch [ 95/150] 	 Loss: 0.01094     Accuracy: 99.63% 	 Test Loss: 0.71921     Test Accuracy: 88.84%
# Epoch [ 96/150] 	 Loss: 0.01317     Accuracy: 99.57% 	 Test Loss: 0.68855     Test Accuracy: 89.04%
# Epoch [ 97/150] 	 Loss: 0.00877     Accuracy: 99.70% 	 Test Loss: 0.71885     Test Accuracy: 88.42%
# Epoch [ 98/150] 	 Loss: 0.00935     Accuracy: 99.69% 	 Test Loss: 0.88894     Test Accuracy: 86.65%
# Epoch [ 99/150] 	 Loss: 0.00487     Accuracy: 99.85% 	 Test Loss: 0.58345     Test Accuracy: 90.23%
# Epoch [100/150] 	 Loss: 0.00346     Accuracy: 99.89% 	 Test Loss: 0.68956     Test Accuracy: 89.72%
# Epoch [101/150] 	 Loss: 0.00424     Accuracy: 99.84% 	 Test Loss: 0.62970     Test Accuracy: 89.80%
# Epoch [102/150] 	 Loss: 0.00883     Accuracy: 99.70% 	 Test Loss: 1.22902     Test Accuracy: 83.61%
# Epoch [103/150] 	 Loss: 0.01886     Accuracy: 99.40% 	 Test Loss: 0.57550     Test Accuracy: 90.03%
# Epoch [104/150] 	 Loss: 0.01027     Accuracy: 99.68% 	 Test Loss: 0.60570     Test Accuracy: 90.15%
# Epoch [105/150] 	 Loss: 0.00259     Accuracy: 99.92% 	 Test Loss: 0.56621     Test Accuracy: 90.87%
# Epoch [106/150] 	 Loss: 0.00137     Accuracy: 99.97% 	 Test Loss: 0.63122     Test Accuracy: 90.10%
# Epoch [107/150] 	 Loss: 0.00217     Accuracy: 99.94% 	 Test Loss: 0.58964     Test Accuracy: 89.98%
# Epoch [108/150] 	 Loss: 0.00186     Accuracy: 99.94% 	 Test Loss: 0.59194     Test Accuracy: 90.54%
# Epoch [109/150] 	 Loss: 0.01844     Accuracy: 99.41% 	 Test Loss: 0.88421     Test Accuracy: 86.63%
# Epoch [110/150] 	 Loss: 0.02496     Accuracy: 99.26% 	 Test Loss: 0.69995     Test Accuracy: 88.02%
# Epoch [111/150] 	 Loss: 0.00748     Accuracy: 99.74% 	 Test Loss: 0.59695     Test Accuracy: 90.04%
# Epoch [112/150] 	 Loss: 0.00591     Accuracy: 99.82% 	 Test Loss: 0.54000     Test Accuracy: 90.35%
# Epoch [113/150] 	 Loss: 0.00320     Accuracy: 99.90% 	 Test Loss: 0.57468     Test Accuracy: 90.46%
# Epoch [114/150] 	 Loss: 0.00138     Accuracy: 99.96% 	 Test Loss: 0.61672     Test Accuracy: 90.28%
# Epoch [115/150] 	 Loss: 0.00069     Accuracy: 99.99% 	 Test Loss: 0.55195     Test Accuracy: 90.90%
# Epoch [116/150] 	 Loss: 0.00016     Accuracy: 100.00% 	 Test Loss: 0.54168     Test Accuracy: 91.56%
# Epoch [117/150] 	 Loss: 0.00007     Accuracy: 100.00% 	 Test Loss: 0.53675     Test Accuracy: 91.66%
# Epoch [118/150] 	 Loss: 0.00040     Accuracy: 99.99% 	 Test Loss: 0.75361     Test Accuracy: 89.00%
# Epoch [119/150] 	 Loss: 0.03244     Accuracy: 98.99% 	 Test Loss: 0.74622     Test Accuracy: 87.02%
# Epoch [120/150] 	 Loss: 0.01562     Accuracy: 99.47% 	 Test Loss: 0.54752     Test Accuracy: 90.07%
# Epoch [121/150] 	 Loss: 0.00272     Accuracy: 99.92% 	 Test Loss: 0.55756     Test Accuracy: 90.26%
# Epoch [122/150] 	 Loss: 0.00141     Accuracy: 99.97% 	 Test Loss: 0.50625     Test Accuracy: 91.20%
# Epoch [123/150] 	 Loss: 0.00023     Accuracy: 100.00% 	 Test Loss: 0.50788     Test Accuracy: 91.39%
# Epoch [124/150] 	 Loss: 0.00020     Accuracy: 100.00% 	 Test Loss: 0.51515     Test Accuracy: 91.35%
# Epoch [125/150] 	 Loss: 0.00008     Accuracy: 100.00% 	 Test Loss: 0.50717     Test Accuracy: 91.42%
# Epoch [126/150] 	 Loss: 0.00007     Accuracy: 100.00% 	 Test Loss: 0.51035     Test Accuracy: 91.38%
# Epoch [127/150] 	 Loss: 0.00005     Accuracy: 100.00% 	 Test Loss: 0.50997     Test Accuracy: 91.43%
# Epoch [128/150] 	 Loss: 0.00003     Accuracy: 100.00% 	 Test Loss: 0.51016     Test Accuracy: 91.41%
# Epoch [129/150] 	 Loss: 0.00005     Accuracy: 100.00% 	 Test Loss: 0.51442     Test Accuracy: 91.51%
# Epoch [130/150] 	 Loss: 0.05158     Accuracy: 98.45% 	 Test Loss: 0.63629     Test Accuracy: 87.45%
# Epoch [131/150] 	 Loss: 0.01285     Accuracy: 99.59% 	 Test Loss: 0.50834     Test Accuracy: 90.06%
# Epoch [132/150] 	 Loss: 0.00211     Accuracy: 99.95% 	 Test Loss: 0.47548     Test Accuracy: 90.93%
# Epoch [133/150] 	 Loss: 0.00058     Accuracy: 99.99% 	 Test Loss: 0.47564     Test Accuracy: 91.19%
# Epoch [134/150] 	 Loss: 0.00029     Accuracy: 100.00% 	 Test Loss: 0.47306     Test Accuracy: 91.22%
# Epoch [135/150] 	 Loss: 0.00175     Accuracy: 99.96% 	 Test Loss: 0.50686     Test Accuracy: 90.74%
# Epoch [136/150] 	 Loss: 0.00038     Accuracy: 100.00% 	 Test Loss: 0.50882     Test Accuracy: 91.03%
# Epoch [137/150] 	 Loss: 0.00031     Accuracy: 99.99% 	 Test Loss: 0.51620     Test Accuracy: 90.96%
# Epoch [138/150] 	 Loss: 0.00016     Accuracy: 100.00% 	 Test Loss: 0.50006     Test Accuracy: 91.17%
# Epoch [139/150] 	 Loss: 0.00008     Accuracy: 100.00% 	 Test Loss: 0.50151     Test Accuracy: 91.29%
# Epoch [140/150] 	 Loss: 0.00005     Accuracy: 100.00% 	 Test Loss: 0.50328     Test Accuracy: 91.37%
# Epoch [141/150] 	 Loss: 0.00003     Accuracy: 100.00% 	 Test Loss: 0.50639     Test Accuracy: 91.31%
# Epoch [142/150] 	 Loss: 0.00002     Accuracy: 100.00% 	 Test Loss: 0.50168     Test Accuracy: 91.40%
# Epoch [143/150] 	 Loss: 0.00002     Accuracy: 100.00% 	 Test Loss: 0.50686     Test Accuracy: 91.22%
# Epoch [144/150] 	 Loss: 0.00002     Accuracy: 100.00% 	 Test Loss: 0.50574     Test Accuracy: 91.42%
# Epoch [145/150] 	 Loss: 0.00002     Accuracy: 100.00% 	 Test Loss: 0.50728     Test Accuracy: 91.39%
# Epoch [146/150] 	 Loss: 0.00001     Accuracy: 100.00% 	 Test Loss: 0.51196     Test Accuracy: 91.41%
# Epoch [147/150] 	 Loss: 0.00001     Accuracy: 100.00% 	 Test Loss: 0.51439     Test Accuracy: 91.39%
# Epoch [148/150] 	 Loss: 0.00001     Accuracy: 100.00% 	 Test Loss: 0.51570     Test Accuracy: 91.36%
# Epoch [149/150] 	 Loss: 0.00001     Accuracy: 100.00% 	 Test Loss: 0.51937     Test Accuracy: 91.36%
# Epoch [150/150] 	 Loss: 0.00001     Accuracy: 100.00% 	 Test Loss: 0.51986     Test Accuracy: 91.44%

# %%
# the best accuracy
best_epoch = np.argmax(test_accuracies)
print(f"\nBest epoch: {best_epoch + 1} with test accuracy: {test_accuracies[best_epoch]:.2f}%")
# Out:
# Best epoch: 117 with test accuracy: 91.66%

# %% [markdown]
# # Plot results

# %%
plt.plot(train_losses, label='train_losses')
plt.plot(test_losses, label='test_losses')
plt.legend()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(test_accuracies, label='test_accuracy')
plt.legend()
